# %%
import numpy as np
import matplotlib.pyplot as plt

x_data = [1.0, 2.0, 3.0]
y_data = [2.0, 4.0, 6.0]

learning_rate = 0.02


# our model for the forward pass
def forward(x):
    return x * w



# Loss function
def loss(x, y):
    y_pred = forward(x)
    return (y_pred - y) * (y_pred - y)


def gradient_descent(x,y):
    return 2 * x *(x * w - y) # the deritive with respect to w - gradient

w_list = []
mse_list = []
w = 0
print("before", 4 , " = ", forward(4))

for epoch in range(25):
    for x_val, y_val in zip(x_data, y_data):
        grad = gradient_descent(x_val, y_val)
        w = w - learning_rate * grad
        print("\tgrad:",x_val, y_val, grad)
        l = loss(x_val, y_val)
        l_sum = 0
        l_sum += l
        #print("\t", x_val, y_val, y_pred_val, l)
        print("progress:",epoch, "w=", w, "loss=",l)
        #print("MSE=", l_sum / 3)
        w_list.append(w)
        mse_list.append(l_sum / 3)
print("after", 4 , " = ", forward(4))

plt.plot(w_list, mse_list)
plt.ylabel('Loss')
plt.xlabel('w')
plt.show()
# Out:
# before 4  =  0
# 	grad: 1.0 2.0 -4.0
# progress: 0 w= 0.08 loss= 3.6864
# 	grad: 2.0 4.0 -15.36
# progress: 0 w= 0.3872 loss= 10.40449536
# 	grad: 3.0 6.0 -29.0304
# progress: 0 w= 0.967808 loss= 9.588782923775998
# 	grad: 1.0 2.0 -2.064384
# progress: 1 w= 1.00909568 loss= 0.9818913713946625
# 	grad: 2.0 4.0 -7.9272345600000005
# progress: 1 w= 1.1676403711999999 loss= 2.771290206624296
# 	grad: 3.0 6.0 -14.982473318400004
# progress: 1 w= 1.467289837568 loss= 2.5540210544249513
# 	grad: 1.0 2.0 -1.0654203248640002
# progress: 2 w= 1.4885982440652799 loss= 0.26153175597311507
# 	grad: 2.0 4.0 -4.091214047477761
# progress: 2 w= 1.5704225250148351 loss= 0.7381472280585197
# 	grad: 3.0 6.0 -7.732394549732966
# progress: 2 w= 1.7250704160094945 loss= 0.680276485378731
# 	grad: 1.0 2.0 -0.549859167981011
# progress: 3 w= 1.7360675993691148 loss= 0.06966031210278209
# 	grad: 2.0 4.0 -2.1114592050470815
# progress: 3 w= 1.7782967834700565 loss= 0.19660926487889208
# ...

# %%
#The house price predicting

import numpy as np
import matplotlib.pyplot as plt

square_of_the_house = [50, 60, 10, 90]
year_biuld = [1999,1990,1993,2014];
house_prices = [250, 340, 20, 800]


# our model for the forward pass
def forward(x,year):
    return pow(x,2) * w + year * w2 


# Loss function
def loss(x, y, year):
    y_pred = forward(x,year)
    return (y_pred - y) * (y_pred - y)


w_list = []
w2_list = []
mse_list = []

for w in np.arange(-1, 2, 0.1):
    for w2 in np.arange(-1,2,0.1):
        print("w=", w ,"w2=", w2 )
        l_sum = 0
        for x_val, y_val, year_val  in zip(square_of_the_house, house_prices ,year_biuld):
            y_pred_val = forward(x_val,year_val)
            l = loss(x_val, y_val, year_val)
            l_sum += l
            print("\t", x_val, y_val,year_val, y_pred_val, l)
        print("MSE=", l_sum / 4)
        w_list.append(w)
        w2_list.append(w2)
        mse_list.append(l_sum / 4)

plt.plot(w_list, mse_list)
plt.ylabel('Loss')
plt.xlabel('weight for square')
plt.plot(w2_list, mse_list)
plt.ylabel('Loss')
plt.xlabel('weight for year')
plt.show()
# Out:
# w= -1.0 w2= -1.0
# 	 50 250 1999 -4499.0 22553001.0
# 	 60 340 1990 -5590.0 35164900.0
# 	 10 20 1993 -2093.0 4464769.0
# 	 90 800 2014 -10114.0 119115396.0
# MSE= 45324516.5
# w= -1.0 w2= -0.9
# 	 50 250 1999 -4299.1 20694310.810000002
# 	 60 340 1990 -5391.0 32844361.0
# 	 10 20 1993 -1893.7 3662247.69
# 	 90 800 2014 -9912.6 114759798.76
# MSE= 42990179.565
# w= -1.0 w2= -0.8
# 	 50 250 1999 -4099.2 18915540.639999997
# 	 60 340 1990 -5192.0 30603024.0
# 	 10 20 1993 -1694.4 2939167.3600000003
# 	 90 800 2014 -9711.2 110485325.44000001
# MSE= 40735764.36
# w= -1.0 w2= -0.7000000000000001
# 	 50 250 1999 -3899.3 17216690.490000002
# 	 60 340 1990 -4993.0 28440889.0
# 	 10 20 1993 -1495.1000000000001 2295528.0100000002
# 	 90 800 2014 -9509.8 106291976.03999999
# MSE= 38561270.885
# w= -1.0 w2= -0.6000000000000001
# 	 50 250 1999 -3699.4 15597760.360000001
# 	 60 340 1990 -4794.0 26357956.0
# 	 10 20 1993 -1295.8000000000002 1731329.6400000004
# ...

# %%
plt.plot(w2_list, mse_list)
plt.ylabel('Loss')
plt.xlabel('weight for year')
plt.show()

# %%
t = torch.Tensor()
print(t.dtype)
print(t.device)
# Out:
# torch.float32
# cpu

# %%
device = torch.device("cuda:0")
device
# Out:
# device(type='cuda', index=0)
